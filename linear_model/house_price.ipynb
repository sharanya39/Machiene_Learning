# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn import linear_model
from sklearn.linear_model import LinearRegression
SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area in sq.ft')
plt.ylabel('Price in USD')
plt.plot(df.area,df.price,color="green",marker='*')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
reg.predict([[3200]])
# Out:
# /home/sharanya/Machiene_learning/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([615136.98630137])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
df1=pd.read_csv('areas.csv')
df1.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=reg.predict(df1)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df1['prices']=p
df1.to_csv('prediction.csv',index=False)

# %%
plt.xlabel('Area in sq.ft')
plt.ylabel('Price in USD')
plt.plot(df1.area,df1.prices,color="green",marker='*')

# %%
reg.predict([[10000]])
# Out:
# /home/sharanya/Machiene_learning/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1538493.15068493])
